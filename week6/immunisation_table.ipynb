# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy() #give us a style state to go back to

# %%
"""Opening the data set."""

imm_01 = pd.read_csv("immunisation_table01.csv").iloc[:-1]

imm_02 = pd.read_csv("immunisation_table02.csv").iloc[:-1]

imm_03 = pd.read_csv("immunisation_table03.csv").iloc[:-1]

filepath = "2006_all_students.xls"
local_data = pd.read_excel(filepath, sheetname="5", skiprows=2)
LD_perage = pd.read_excel(filepath, sheetname="2", skiprows=2)

filepathCensus = "CensusData_01.xls"
#print(os.path.isfile(filepathCensus))

census = pd.read_excel(filepathCensus, skiprows=8)

# %%
imm_01
# Out:
#   State      Age Group  % DTP  % Polio  % HIB  % Hep B % MMR  % Pneumo % MenC  \
# 0   ACT  12-<15 Months  96.11    95.99  95.71    95.90   n/a     95.79    n/a
# 1   NSW  12-<15 Months  94.41    94.37  94.08    94.35   n/a     93.97    n/a
# 2   VIC  12-<15 Months  94.69    94.65  94.28    94.55   n/a     94.27    n/a
# 3   QLD  12-<15 Months  94.73    94.71  94.53    94.75   n/a     94.45    n/a
# 4    SA  12-<15 Months  94.54    94.50  94.26    94.49   n/a     94.23    n/a
# 5    WA  12-<15 Months  93.74    93.71  93.43    93.56   n/a     93.35    n/a
# 6   TAS  12-<15 Months  94.46    94.39  94.13    94.55   n/a     94.18    n/a
# 7    NT  12-<15 Months  93.80    93.74  93.40    93.74   n/a     93.45    n/a
#
#   % Varicella  % Fully Immunised*
# 0         n/a               95.14
# 1         n/a               93.48
# 2         n/a               93.66
# 3         n/a               94.12
# 4         n/a               93.85
# 5         n/a               92.84
# 6         n/a               93.76
# 7         n/a               92.80

# %%
imm_02
# Out:
#   State      Age Group  % DTP**  % Polio  % HIB  % Hep B  % MMR % Pneumo  \
# 0   ACT  24-<27 Months    96.04    96.92  95.97    96.88  93.85      n/a
# 1   NSW  24-<27 Months    94.97    96.04  94.92    95.90  92.86      n/a
# 2   VIC  24-<27 Months    95.43    96.50  95.60    96.30  93.44      n/a
# 3   QLD  24-<27 Months    95.39    96.23  95.66    96.10  93.75      n/a
# 4    SA  24-<27 Months    94.97    96.21  95.28    96.05  93.34      n/a
# 5    WA  24-<27 Months    94.70    96.14  95.04    95.88  92.11      n/a
# 6   TAS  24-<27 Months    95.62    96.54  96.22    96.51  94.34      n/a
# 7    NT  24-<27 Months    94.61    96.15  95.60    96.23  91.89      n/a
#
#    % Men C***  % Varicella***  % Fully Immunised***
# 0       95.61           93.63                 91.92
# 1       94.86           92.79                 90.47
# 2       95.35           93.57                 91.36
# 3       95.59           93.36                 92.10
# 4       95.31           93.21                 91.19
# 5       94.77           91.77                 90.12
# 6       96.27           93.83                 92.03
# 7       95.16           90.96                 88.54

# %%
imm_03
# Out:
#   State      Age Group  % DTP  % Polio % HIB % Hep B  % MMR % Pneumo % MenC  \
# 0   ACT  60-<63 Months  94.27    94.32   n/a     n/a  94.57      n/a    n/a
# 1   NSW  60-<63 Months  94.14    94.20   n/a     n/a  94.32      n/a    n/a
# 2   VIC  60-<63 Months  94.55    94.64   n/a     n/a  94.68      n/a    n/a
# 3   QLD  60-<63 Months  94.18    94.18   n/a     n/a  94.34      n/a    n/a
# 4    SA  60-<63 Months  94.13    94.16   n/a     n/a  94.40      n/a    n/a
# 5    WA  60-<63 Months  92.19    92.24   n/a     n/a  92.87      n/a    n/a
# 6   TAS  60-<63 Months  94.96    94.98   n/a     n/a  94.75      n/a    n/a
# 7    NT  60-<63 Months  93.15    93.18   n/a     n/a  93.66      n/a    n/a
#
#   % Varicella  % Fully Immunised
# 0         n/a              93.52
# 1         n/a              93.48
# 2         n/a              93.77
# 3         n/a              93.48
# 4         n/a              93.39
# 5         n/a              91.45
# 6         n/a              94.06
# 7         n/a              92.39

# %%
intervals = range(len(imm_01["State"]))
labels = list(imm_01["State"])
index = np.arange(len(imm_01["State"]))

plt.subplot(111)

plt.bar(index - 0.2, imm_01["% Fully Immunised*"], width=0.2, align="center", label="Cohort 1 (12-<15 Months)");
plt.bar(index, imm_02["% Fully Immunised***"], width=0.2, align="center", label="Cohort 2 (24-<27 Months)");
plt.bar(index + 0.2, imm_03["% Fully Immunised"], width=0.2, align="center", label="Cohort 3 (60-<63 Months)");

plt.xticks(intervals, labels);
plt.ylim([80,100])
plt.title("Percentage of Immunisation per State");
plt.ylabel("% Immunisation. (Range 90-100%)");
plt.xlabel("State");
plt.legend();

# %%
"""Merging all the Cohort as a percentage."""

imm_addition = []
for i in range(len(state_name)):
    imm_addition.append(imm_01["% Fully Immunised*"][i] + imm_02["% Fully Immunised***"][i] + imm_03["% Fully Immunised"][i])
# imm_addition


sorted_imm = sorted(zip(imm_01["State"], imm_addition))
sorted_imm


percentage_imm = []
for i in range(len(sorted_imm)):
    percentage_imm.append(sorted_imm[i][1] / 3)
percentage_imm

intervals = range(len(sorted_imm))

plt.bar(intervals, percentage_imm);

plt.xticks(intervals, labels);
plt.ylim([80,100])
plt.title("Percentage of Immunisation per State");
plt.ylabel("% Immunisation. (Range 90-100%)");
plt.xlabel("State");

# %%
local_data
# Out:
#                                         State/Provider  Doctorate by Research  \
# 0                                      New South Wales                    NaN
# 1                                         ACPE Limited               0.000000
# 2     Australian College of Applied Psychology Pty Ltd               0.000000
# 3         Australian Film, Television and Radio School               0.000000
# 4                                     Avondale College               0.000000
# 5    Blue Mountains International Hotel Management ...               0.000000
# 6                            Campion Institute Limited               0.000000
# 7                             Charles Sturt University             409.000000
# 8                          East Coast Gestalt Training               0.000000
# 9                              Jansen Newman Institute               0.000000
# 10                         KvB Visual Concepts Pty Ltd               0.000000
# 11                                Macquarie University            1242.000000
# 12                           Moore Theological College               0.000000
# 13                  National Institute of Dramatic Art               0.000000
# 14                       Raffles KVB Institute Pty Ltd               0.000000
# 15                           Southern Cross University             462.000000
# 16                          Sydney College of Divinity              12.000000
# 17   Sydney Institute of Business and Technology Pt...               0.000000
# 18                    Tabor College (NSW) Incorporated               0.000000
# 19           The Australian Institute of Music Limited               0.000000
# 20                         The College of Law Pty Ltd.               0.000000
# 21                       The University of New England             586.000000
# 22                   The University of New South Wales            2446.000000
# 23                         The University of Newcastle             787.000000
# 24                            The University of Sydney            3093.000000
# 25                    University of Technology, Sydney            1051.000000
# 26                        University of Western Sydney             650.000000
# 27                            University of Wollongong             924.000000
# 28                                    Wesley Institute               0.000000
# 29                                     State Sub-total           11662.000000
# ..                                                 ...                    ...
# 82       International College of Hotel Management Inc               0.000000
# 83   South Australian Institute of Business and Tec...               0.000000
# 84                              Tabor College Adelaide               0.000000
# 85          The Flinders University of South Australia             762.000000
# 86                          The University of Adelaide            1638.000000
# 87                       University of South Australia             916.000000
# 88                                     State Sub-total            3316.000000
# 89                                            Tasmania                    NaN
# 90                         Australian Maritime College              15.000000
# 91                              Tabor College Tasmania               0.000000
# 92                              University of Tasmania            1029.000000
# 93                                     State Sub-total            1044.000000
# 94                                  Northern Territory                    NaN
# 95   Batchelor Institute of Indigenous Tertiary Edu...               0.000000
# 96                           Charles Darwin University             187.000000
# 97                                     State Sub-total             187.000000
# 98                        Australian Capital Territory                    NaN
# 99                    Australian Defence Force Academy             154.000000
# 100              Australian International Hotel School               0.000000
# 101                 The Australian National University            2059.000000
# 102                             University of Canberra             211.000000
# 103                                    State Sub-total            2424.000000
# 104                                        Multi-State                    NaN
# 105                     Australian Catholic University             280.000000
# 106  Australian College of Theology Council Incorpo...              15.000000
# 107                                    State Sub-total             295.000000
# 108                                                NaN                    NaN
# 109                                              TOTAL           40511.000000
# 110                                         Total 2005           38953.000000
# 111                                   % change on 2005               0.039997
#
#      Doctorate by Coursework  Master's by Research  Master's by Coursework  \
# 0                        NaN                   NaN                     NaN
# 1                   0.000000              0.000000                0.000000
# 2                   0.000000              0.000000                0.000000
# 3                   0.000000              0.000000               41.000000
# 4                   0.000000              1.000000              143.000000
# 5                   0.000000              0.000000                0.000000
# 6                   0.000000              0.000000                0.000000
# 7                  80.000000             39.000000             4996.000000
# 8                   0.000000              0.000000                0.000000
# 9                   0.000000              0.000000                0.000000
# 10                  0.000000              0.000000                0.000000
# 11                  0.000000            215.000000             7282.000000
# 12                  0.000000              1.000000               43.000000
# 13                  0.000000              0.000000                0.000000
# 14                  0.000000              0.000000                0.000000
# 15                  0.000000             59.000000             1546.000000
# 16                  8.000000              7.000000              616.000000
# 17                  0.000000              0.000000                0.000000
# 18                  0.000000              0.000000                0.000000
# 19                  0.000000              0.000000                0.000000
# 20                  0.000000              0.000000                0.000000
# 21                 10.000000            201.000000             1996.000000
# 22                  0.000000            576.000000             7530.000000
# 23                388.000000            310.000000             3022.000000
# 24                 37.000000            751.000000             8534.000000
# 25                  0.000000            278.000000             7423.000000
# 26                  1.000000             94.000000             3220.000000
# 27                  6.000000            253.000000             4695.000000
# 28                  0.000000              0.000000               52.000000
# 29                530.000000           2785.000000            51139.000000
# ..                       ...                   ...                     ...
# 82                  0.000000              0.000000                0.000000
# 83                  0.000000              0.000000                0.000000
# 84                 13.000000              0.000000               33.000000
# 85                 78.000000            122.000000             2430.000000
# 86                 23.000000            209.000000             2453.000000
# 87                355.000000             77.000000             4969.000000
# 88                469.000000            408.000000             9967.000000
# 89                       NaN                   NaN                     NaN
# 90                  0.000000              4.000000               36.000000
# 91                  0.000000              0.000000                0.000000
# 92                  0.000000            239.000000              798.000000
# 93                  0.000000            243.000000              834.000000
# 94                       NaN                   NaN                     NaN
# 95                  0.000000              0.000000                0.000000
# 96                 17.000000             31.000000              318.000000
# 97                 17.000000             31.000000              318.000000
# 98                       NaN                   NaN                     NaN
# 99                 17.000000             35.000000              617.000000
# 100                 0.000000              0.000000                0.000000
# 101                14.000000            130.000000             2242.000000
# 102                 1.000000             67.000000             1869.000000
# 103                32.000000            232.000000             4728.000000
# 104                      NaN                   NaN                     NaN
# 105                 9.000000             70.000000             1824.000000
# 106                56.000000             22.000000              473.000000
# 107                65.000000             92.000000             2297.000000
# 108                      NaN                   NaN                     NaN
# 109              1806.000000           8956.000000           148705.000000
# 110              1841.000000           9248.000000           146299.000000
# 111                -0.019011             -0.031574                0.016446
#
#      Other Postgraduate  Sub-total Postgraduate       Bachelor  \
# 0                   NaN                     NaN            NaN
# 1              0.000000                0.000000     840.000000
# 2            717.000000              717.000000     854.000000
# 3             73.000000              114.000000       0.000000
# 4             33.000000              177.000000     937.000000
# 5              2.000000                2.000000      34.000000
# 6              0.000000                0.000000      16.000000
# 7           2951.000000             8475.000000   21475.000000
# 8             60.000000               60.000000       0.000000
# 9             35.000000               35.000000      19.000000
# 10             0.000000                0.000000     112.000000
# 11          2264.000000            11003.000000   17930.000000
# 12             0.000000               44.000000     268.000000
# 13            10.000000               10.000000     159.000000
# 14             0.000000                0.000000      95.000000
# 15           612.000000             2679.000000   10365.000000
# 16            51.000000              694.000000     988.000000
# 17             0.000000                0.000000       0.000000
# 18             5.000000                5.000000      46.000000
# 19            12.000000               12.000000     323.000000
# 20           843.000000              843.000000       0.000000
# 21          2307.000000             5100.000000   11754.000000
# 22          3156.000000            13708.000000   23520.000000
# 23          1351.000000             5858.000000   17406.000000
# 24          2131.000000            14546.000000   30027.000000
# 25          2590.000000            11342.000000   20898.000000
# 26          1313.000000             5278.000000   26960.000000
# 27           929.000000             6807.000000   13711.000000
# 28            72.000000              124.000000     136.000000
# 29         21517.000000            87633.000000  198873.000000
# ..                  ...                     ...            ...
# 82             0.000000                0.000000       1.000000
# 83             0.000000                0.000000       0.000000
# 84            77.000000              123.000000     590.000000
# 85          1069.000000             4461.000000   10611.000000
# 86          1242.000000             5565.000000   13075.000000
# 87          2420.000000             8737.000000   23736.000000
# 88          4925.000000            19085.000000   48104.000000
# 89                  NaN                     NaN            NaN
# 90           113.000000              168.000000     414.000000
# 91             0.000000                0.000000      40.000000
# 92           785.000000             2851.000000   13846.000000
# 93           898.000000             3019.000000   14300.000000
# 94                  NaN                     NaN            NaN
# 95            20.000000               20.000000     144.000000
# 96           464.000000             1017.000000    3781.000000
# 97           484.000000             1037.000000    3925.000000
# 98                  NaN                     NaN            NaN
# 99           402.000000             1225.000000     995.000000
# 100            0.000000                0.000000       0.000000
# 101         1144.000000             5589.000000    8533.000000
# 102          928.000000             3076.000000    7652.000000
# 103         2474.000000             9890.000000   17180.000000
# 104                 NaN                     NaN            NaN
# 105         1676.000000             3859.000000    9214.000000
# 106          546.000000             1112.000000     842.000000
# 107         2222.000000             4971.000000   10056.000000
# 108                 NaN                     NaN            NaN
# 109        70471.000000           270449.000000  669817.000000
# 110        67163.000000           263504.000000  652731.000000
# 111            0.049253                0.026356       0.026176
#
#      Associate Degree  Other Undergraduate  Sub-total Undergraduate  \
# 0                 NaN                  NaN                      NaN
# 1            0.000000             0.000000               840.000000
# 2            4.000000             1.000000               859.000000
# 3            0.000000             0.000000                 0.000000
# 4            0.000000            94.000000              1031.000000
# 5            0.000000             9.000000                43.000000
# 6            0.000000             0.000000                16.000000
# 7         2504.000000           171.000000             24150.000000
# 8            0.000000             0.000000                 0.000000
# 9            0.000000             0.000000                19.000000
# 10           0.000000             0.000000               112.000000
# 11           0.000000           211.000000             18141.000000
# 12           0.000000             0.000000               268.000000
# 13           0.000000             1.000000               160.000000
# 14           0.000000             0.000000                95.000000
# 15         509.000000             0.000000             10874.000000
# 16           0.000000            80.000000              1068.000000
# 17           0.000000           572.000000               572.000000
# 18           0.000000             0.000000                46.000000
# 19           0.000000            37.000000               360.000000
# 20           0.000000             0.000000                 0.000000
# 21           0.000000           416.000000             12170.000000
# 22           0.000000            22.000000             23542.000000
# 23           0.000000             0.000000             17406.000000
# 24           0.000000           197.000000             30224.000000
# 25           0.000000             3.000000             20901.000000
# 26           0.000000             9.000000             26969.000000
# 27           0.000000           381.000000             14092.000000
# 28           0.000000             0.000000               136.000000
# 29        3017.000000          2204.000000            204094.000000
# ..                ...                  ...                      ...
# 82           0.000000             0.000000                 1.000000
# 83           0.000000           107.000000               107.000000
# 84          17.000000             0.000000               607.000000
# 85           0.000000           213.000000             10824.000000
# 86           0.000000           130.000000             13205.000000
# 87          94.000000            81.000000             23911.000000
# 88         111.000000           686.000000             48901.000000
# 89                NaN                  NaN                      NaN
# 90           0.000000           665.000000              1079.000000
# 91           0.000000             0.000000                40.000000
# 92         328.000000           129.000000             14303.000000
# 93         328.000000           794.000000             15422.000000
# 94                NaN                  NaN                      NaN
# 95           0.000000           254.000000               398.000000
# 96          33.000000            19.000000              3833.000000
# 97          33.000000           273.000000              4231.000000
# 98                NaN                  NaN                      NaN
# 99           0.000000             0.000000               995.000000
# 100          0.000000             0.000000                 0.000000
# 101         12.000000            69.000000              8614.000000
# 102          0.000000             4.000000              7656.000000
# 103         12.000000            73.000000             17265.000000
# 104               NaN                  NaN                      NaN
# 105         89.000000           147.000000              9450.000000
# 106         19.000000           590.000000              1451.000000
# 107        108.000000           737.000000             10901.000000
# 108               NaN                  NaN                      NaN
# 109       4922.000000          8934.000000            683673.000000
# 110       2856.000000          9940.000000            665527.000000
# 111          0.723389            -0.101207                 0.027266
#
#      Enabling Courses  Non-award Courses          TOTAL
# 0                 NaN                NaN            NaN
# 1            0.000000           0.000000     840.000000
# 2            0.000000           0.000000    1576.000000
# 3            0.000000           0.000000     114.000000
# 4            0.000000          38.000000    1246.000000
# 5            0.000000           0.000000      45.000000
# 6            0.000000           0.000000      16.000000
# 7          625.000000         897.000000   34147.000000
# 8            0.000000           0.000000      60.000000
# 9            0.000000           0.000000      54.000000
# 10           0.000000           0.000000     112.000000
# 11           0.000000        1982.000000   31126.000000
# 12           0.000000           0.000000     312.000000
# 13           0.000000           0.000000     170.000000
# 14           0.000000           0.000000      95.000000
# 15         143.000000         187.000000   13883.000000
# 16           0.000000          26.000000    1788.000000
# 17           0.000000           0.000000     572.000000
# 18           0.000000           0.000000      51.000000
# 19           0.000000           0.000000     372.000000
# 20           0.000000           0.000000     843.000000
# 21          52.000000         160.000000   17482.000000
# 22           0.000000        1526.000000   38776.000000
# 23        1825.000000         481.000000   25570.000000
# 24          15.000000        1063.000000   45848.000000
# 25          48.000000         421.000000   32712.000000
# 26          18.000000         670.000000   32935.000000
# 27         292.000000         684.000000   21875.000000
# 28           0.000000           0.000000     260.000000
# 29        3018.000000        8135.000000  302880.000000
# ..                ...                ...            ...
# 82           0.000000           0.000000       1.000000
# 83           0.000000           0.000000     107.000000
# 84           0.000000           0.000000     730.000000
# 85           0.000000         133.000000   15418.000000
# 86          35.000000         485.000000   19290.000000
# 87         300.000000         462.000000   33410.000000
# 88         335.000000        1080.000000   69401.000000
# 89                NaN                NaN            NaN
# 90           0.000000           1.000000    1248.000000
# 91           0.000000           0.000000      40.000000
# 92         304.000000          13.000000   17471.000000
# 93         304.000000          14.000000   18759.000000
# 94                NaN                NaN            NaN
# 95         254.000000           0.000000     672.000000
# 96         536.000000          10.000000    5396.000000
# 97         790.000000          10.000000    6068.000000
# 98                NaN                NaN            NaN
# 99           0.000000         263.000000    2483.000000
# 100          0.000000           0.000000       0.000000
# 101          0.000000         350.000000   14553.000000
# 102         16.000000         110.000000   10858.000000
# 103         16.000000         723.000000   27894.000000
# 104               NaN                NaN            NaN
# 105          0.000000         658.000000   13967.000000
# 106          0.000000           0.000000    2563.000000
# 107          0.000000         658.000000   16530.000000
# 108               NaN                NaN            NaN
# 109       7309.000000       22715.000000  984146.000000
# 110       5704.000000       22442.000000  957177.000000
# 111          0.281381           0.012165       0.028176
#
# [112 rows x 14 columns]

# %%
state_subtotal = local_data[local_data["State/Provider"] == "State Sub-total"][:-1]
state_subtotal
# Out:
#       State/Provider  Doctorate by Research  Doctorate by Coursework  \
# 29   State Sub-total                11662.0                    530.0
# 53   State Sub-total                10760.0                    234.0
# 67   State Sub-total                 6497.0                    323.0
# 77   State Sub-total                 4326.0                    136.0
# 88   State Sub-total                 3316.0                    469.0
# 93   State Sub-total                 1044.0                      0.0
# 97   State Sub-total                  187.0                     17.0
# 103  State Sub-total                 2424.0                     32.0
#
#      Master's by Research  Master's by Coursework  Other Postgraduate  \
# 29                 2785.0                 51139.0             21517.0
# 53                 2931.0                 39757.0             19323.0
# 67                 1271.0                 29858.0             11536.0
# 77                  963.0                  9807.0              7092.0
# 88                  408.0                  9967.0              4925.0
# 93                  243.0                   834.0               898.0
# 97                   31.0                   318.0               484.0
# 103                 232.0                  4728.0              2474.0
#
#      Sub-total Postgraduate  Bachelor  Associate Degree  Other Undergraduate  \
# 29                  87633.0  198873.0            3017.0               2204.0
# 53                  73005.0  172973.0             197.0               1982.0
# 67                  49485.0  129171.0             755.0               1774.0
# 77                  22324.0   75235.0             361.0                411.0
# 88                  19085.0   48104.0             111.0                686.0
# 93                   3019.0   14300.0             328.0                794.0
# 97                   1037.0    3925.0              33.0                273.0
# 103                  9890.0   17180.0              12.0                 73.0
#
#      Sub-total Undergraduate  Enabling Courses  Non-award Courses     TOTAL
# 29                  204094.0            3018.0             8135.0  302880.0
# 53                  175152.0             210.0             3327.0  251694.0
# 67                  131700.0            1715.0             7136.0  190036.0
# 77                   76007.0             921.0             1632.0  100884.0
# 88                   48901.0             335.0             1080.0   69401.0
# 93                   15422.0             304.0               14.0   18759.0
# 97                    4231.0             790.0               10.0    6068.0
# 103                  17265.0              16.0              723.0   27894.0

# %%
state_name = local_data["State/Provider"][local_data["Sub-total Undergraduate"].isnull()][:-2]
state_name
# Out:
# 0                  New South Wales
# 30                        Victoria
# 54                      Queensland
# 68               Western Australia
# 78                 South Australia
# 89                        Tasmania
# 94              Northern Territory
# 98    Australian Capital Territory
# Name: State/Provider, dtype: object

# %%
sum(state_subtotal["Sub-total Undergraduate"])
age_percentage_tertiary = sum(LD_perage.iloc[6:11]["Sub-total Undergraduate"]) / sum(state_subtotal["Sub-total Undergraduate"]) * 100
age_percentage_tertiary
# Out:
# 32.250004459162987

# %%
subtotal_undergrad_byage = state_subtotal["Sub-total Undergraduate"] / age_percentage_tertiary
subtotal_undergrad_byage
# Out:
# 29     6328.495249
# 53     5431.069016
# 67     4083.720366
# 77     2356.805876
# 88     1516.309868
# 93      478.201484
# 97      131.193780
# 103     535.348763
# Name: Sub-total Undergraduate, dtype: float64

# %%
intervals = range(len(state_subtotal["Sub-total Undergraduate"]))
labels = list(state_name)

plt.bar(intervals, subtotal_undergrad_byage);

plt.xticks(intervals, labels);
plt.title("Undergraduate Enrolment in 2006 (Age 20-24 years old)");
plt.ylabel("Enrolment Amount");
plt.xlabel("State");

# %%
"""Year 12 enrolled."""
yr12_census = census.iloc[2:10]
yr12_census
# Out:
#   Age in Single Years (AGEP)                    Unnamed: 1  20 years  \
# 2                        NaN  Australian Capital Territory    4462.0
# 3                        NaN            Northern Territory    1065.0
# 4                        NaN                      Tasmania    3498.0
# 5                        NaN             Western Australia   18042.0
# 6                        NaN               South Australia   12918.0
# 7                        NaN                    Queensland   37669.0
# 8                        NaN                      Victoria   48825.0
# 9                        NaN               New South Wales   57347.0
#
#    21 years  22 years  23 years  24 years     TOTAL
# 2    4448.0    4429.0    4439.0    4448.0   22226.0
# 3    1063.0    1181.0    1338.0    1327.0    5974.0
# 4    3525.0    3376.0    3145.0    3027.0   16571.0
# 5   17848.0   17017.0   16586.0   16006.0   85499.0
# 6   12925.0   12765.0   12333.0   11807.0   62748.0
# 7   37797.0   37025.0   36878.0   35357.0  184726.0
# 8   49801.0   48441.0   48017.0   47224.0  242308.0
# 9   57651.0   56503.0   57305.0   57126.0  285932.0

# %%
yr12_statename = yr12_census["Unnamed: 1"]
yr12_statename
# Out:
# 2    Australian Capital Territory
# 3              Northern Territory
# 4                        Tasmania
# 5               Western Australia
# 6                 South Australia
# 7                      Queensland
# 8                        Victoria
# 9                 New South Wales
# Name: Unnamed: 1, dtype: object

# %%
intervals = range(len(yr12_census["TOTAL"]))
labels = list(yr12_statename)

plt.bar(intervals, yr12_census["TOTAL"]);

plt.xticks(intervals, labels);
plt.title("Year 12 graduates in 2006");
plt.ylabel("Graduates");
plt.xlabel("State");

# %%
"""Year 12 Graduates versus Undergrad Enrollment"""

undergrad_plotdata = []
sorted_undergrad = sorted(zip(state_name, state_subtotal["Sub-total Undergraduate"]))
for i in range(len(sorted_undergrad)):
    undergrad_plotdata.append(sorted_undergrad[i][1])
# undergrad_plotdata

yr12_plotdata = []
sorted_yr12 = sorted(zip(yr12_statename, yr12_census["TOTAL"]))
for i in range(len(sorted_yr12)):
    yr12_plotdata.append(sorted_yr12[i][1])
# yr12_plotdata


index = np.arange(len(sorted_undergrad))
intervals = range(len(sorted_undergrad))
labels = list(sorted(state_name));

plt.bar(index - 0.2, yr12_plotdata, width=0.2, align="center", label="Year 12 Graduates");
plt.bar(index, undergrad_plotdata, width=0.2, align="center", label="Undergrad Enrollment");


plt.xticks(intervals, labels);
plt.title("Year 12 Graduates versus Undergrad Enrollment");
plt.xlabel("State");
plt.ylabel("Enrollment Amount");
plt.legend();

# %%
"""Percentage between highschool graduates vs undergrad enrollment"""

# yr12_plotdata
# undergrad_plotdata

percentage_edu = []
for i in range(len(yr12_plotdata)):
    percentage_edu.append(undergrad_plotdata[i] / yr12_plotdata[i]* 100)
# percentage_edu

index = np.arange(len(yr12_plotdata))
intervals = range(len(yr12_plotdata))
labels = list(sorted(state_name));

plt.bar(index, percentage_edu, align="center", label="Undergrad Enrollment");


plt.xticks(intervals, labels);
plt.title("Percentage of Undergrad Enrollment againts year 12 graduates.");
plt.xlabel("State");
plt.ylabel("Percentage out of 100%")
plt.legend();

# %%
"""Enrollment Rate versus Immunisation Rate."""

index = np.arange(len(sorted_undergrad))
intervals = range(len(sorted_undergrad))
labels = list(sorted(state_name));

plt.bar(index - 0.2, percentage_imm, width=0.2, align="center", label="Immunised Percentage");
plt.bar(index, percentage_edu, width=0.2, align="center", label="Undergrad Enrollment Percentage");


plt.xticks(intervals, labels);
plt.title("Undergraduate Enrollment versus Imminunisation Percentage");
plt.xlabel("State");
plt.ylabel("Percentage between 60-100%");
plt.ylim([60,100])
plt.legend();

# %%
"""There's no correlation between undergrads and immunisation. Not because they don't enroll in uni, they don't immunise their child"""

# %%
"""Percentage of Undergrads that """

percentage_imm_undergrad = []
for i in range(len(state_name)):
    percentage_imm_undergrad.append(100 - percentage_edu[i] / percentage_imm[i] * 100)
percentage_imm_undergrad
# Out:
# [16.944228540952736,
#  22.81457350426777,
#  22.379459177154274,
#  23.530801705978064,
#  16.030207544286696,
#  0.23276756698513168,
#  22.215796200739021,
#  2.8117243167859698]
