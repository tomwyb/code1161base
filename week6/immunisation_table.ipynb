# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy() #give us a style state to go back to

# %%
if os.path.isfile("immunisation_table.csv"):
    filepath = "immunisation_table.csv"
    print "loading from file"
else:
    filepath = "https://github.com/sheldakristie/code1161base/blob/master/week6/immunisation_table.csv"
    print "loading from the internet"
imm_data = pd.read_csv(filepath)
print "done"
# Out:
# loading from file
# done

# %%
imm_data.head(30)
# Out:
#     State      Age Group    % DTP  % Polio  % HIB  % Hep B  % MMR  % Pneumo  \
# 0     ACT  12-<15 Months    96.11    95.99  95.71    95.90    n/a     95.79
# 1     NSW  12-<15 Months    94.41    94.37  94.08    94.35    n/a     93.97
# 2     VIC  12-<15 Months    94.69    94.65  94.28    94.55    n/a     94.27
# 3     QLD  12-<15 Months    94.73    94.71  94.53    94.75    n/a     94.45
# 4      SA  12-<15 Months    94.54    94.50  94.26    94.49    n/a     94.23
# 5      WA  12-<15 Months    93.74    93.71  93.43    93.56    n/a     93.35
# 6     TAS  12-<15 Months    94.46    94.39  94.13    94.55    n/a     94.18
# 7      NT  12-<15 Months    93.80    93.74  93.40    93.74    n/a     93.45
# 8     AUS  12-<15 Months    94.50    94.47  94.18    94.43    n/a     94.12
# 9   State      Age Group  % DTP**  % Polio  % HIB  % Hep B  % MMR  % Pneumo
# 10    ACT  24-<27 Months    96.04    96.92  95.97    96.88  93.85       n/a
# 11    NSW  24-<27 Months    94.97    96.04  94.92    95.90  92.86       n/a
# 12    VIC  24-<27 Months    95.43    96.50  95.60    96.30  93.44       n/a
# 13    QLD  24-<27 Months    95.39    96.23  95.66    96.10  93.75       n/a
# 14     SA  24-<27 Months    94.97    96.21  95.28    96.05  93.34       n/a
# 15     WA  24-<27 Months    94.70    96.14  95.04    95.88  92.11       n/a
# 16    TAS  24-<27 Months    95.62    96.54  96.22    96.51  94.34       n/a
# 17     NT  24-<27 Months    94.61    96.15  95.60    96.23  91.89       n/a
# 18    AUS  24-<27 Months    95.17    96.24  95.33    96.08  93.17       n/a
# 19  State      Age Group    % DTP  % Polio  % HIB  % Hep B  % MMR  % Pneumo
# 20    ACT  60-<63 Months    94.27    94.32    n/a      n/a  94.57       n/a
# 21    NSW  60-<63 Months    94.14    94.20    n/a      n/a  94.32       n/a
# 22    VIC  60-<63 Months    94.55    94.64    n/a      n/a  94.68       n/a
# 23    QLD  60-<63 Months    94.18    94.18    n/a      n/a  94.34       n/a
# 24     SA  60-<63 Months    94.13    94.16    n/a      n/a  94.40       n/a
# 25     WA  60-<63 Months    92.19    92.24    n/a      n/a  92.87       n/a
# 26    TAS  60-<63 Months    94.96    94.98    n/a      n/a  94.75       n/a
# 27     NT  60-<63 Months    93.15    93.18    n/a      n/a  93.66       n/a
# 28    AUS  60-<63 Months    94.04    94.09    n/a      n/a  94.26       n/a
#
#         % MenC     % Varicella    % Fully Immunised*
# 0          n/a             n/a                 95.14
# 1          n/a             n/a                 93.48
# 2          n/a             n/a                 93.66
# 3          n/a             n/a                 94.12
# 4          n/a             n/a                 93.85
# 5          n/a             n/a                 92.84
# 6          n/a             n/a                 93.76
# 7          n/a             n/a                 92.80
# 8          n/a             n/a                 93.63
# 9   % Men C***  % Varicella***  % Fully Immunised***
# 10       95.61           93.63                 91.92
# 11       94.86           92.79                 90.47
# 12       95.35           93.57                 91.36
# 13       95.59           93.36                 92.10
# 14       95.31           93.21                 91.19
# 15       94.77           91.77                 90.12
# 16       96.27           93.83                 92.03
# 17       95.16           90.96                 88.54
# 18       95.20           93.03                 91.06
# 19      % MenC     % Varicella     % Fully Immunised
# 20         n/a             n/a                 93.52
# 21         n/a             n/a                 93.48
# 22         n/a             n/a                 93.77
# 23         n/a             n/a                 93.48
# 24         n/a             n/a                 93.39
# 25         n/a             n/a                 91.45
# 26         n/a             n/a                 94.06
# 27         n/a             n/a                 92.39
# 28         n/a             n/a                 93.32
